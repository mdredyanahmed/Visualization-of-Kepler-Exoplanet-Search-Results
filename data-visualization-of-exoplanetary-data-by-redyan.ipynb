# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %%
step_1.check()
# Out:
# Correct:

# %%
my_filepath = "../input/kepler-exoplanet-search-results/cumulative.csv"
step_2.check()
# Out:
# Correct:

# %%
my_data = pd.read_csv(my_filepath)
step_3.check()
# Out:
# Correct:

# %%
# Print the first five rows of the data
my_data.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
# Print the last five rows of the data
my_data.tail()
# Out:
#       rowid     kepid kepoi_name kepler_name koi_disposition koi_pdisposition  \
# 9559   9560  10031643  K07984.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9560   9561  10090151  K07985.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9561   9562  10128825  K07986.01         NaN       CANDIDATE        CANDIDATE
# 9562   9563  10147276  K07987.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9563   9564  10156110  K07989.01         NaN  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 9559      0.000              0              0              0  ...
# 9560      0.000              0              1              1  ...
# 9561      0.497              0              0              0  ...
# 9562      0.021              0              0              1  ...
# 9563      0.000              0              0              1  ...
#
#       koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
sns.lineplot(data = my_data)
plt.figure(figsize=(14,14))
plt.xlabel
# Out:
# <function matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)>

# %%
sns.scatterplot(x=my_data['kepid'], y=my_data['koi_score'], hue=my_data['koi_disposition'])
plt.figure(figsize=(20,28))

# %%
sns.lmplot(x='kepid', y='koi_score', hue='koi_disposition', data= my_data)
plt.figure(figsize=(20,28))

# %%
sns.regplot(x=my_data['kepid'], y=my_data['koi_score'])
# Out:
# <AxesSubplot:xlabel='kepid', ylabel='koi_score'>

# %%
sns.swarmplot(x=my_data['koi_disposition'], y=my_data['ra'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 72.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 86.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 70.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='koi_disposition', ylabel='ra'>

# %%
sns.swarmplot(x=my_data['rowid'], y=my_data['koi_disposition'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 77.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 85.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 68.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='rowid', ylabel='koi_disposition'>

# %%
sns.barplot(x=my_data.index, y=my_data['koi_score'])
plt.xlabel('kepid')
# Out:
# Text(0.5, 0, 'kepid')

# %%
sns.distplot(a=my_data['ra'],kde=False)
plt.ylabel('rowid')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'rowid')

# %%
sns.jointplot(x=my_data['koi_score'],y=my_data['ra'],kind='kde')
